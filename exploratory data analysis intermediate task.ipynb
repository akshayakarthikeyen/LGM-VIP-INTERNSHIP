# %% [markdown]
# # LETS GROW MORE VIP INTERNSHIP

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# # INTERMEDIATE LEVEL -TASK1

# %% [markdown]
# # K.AKSHAYA

# %%
#IMPORTING THE LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#load the data set

# %%
df = pd.read_csv(r"global_terrorism.csv",encoding='latin1')
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_11488\795540368.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"global_terrorism.csv",encoding='latin1')

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
data = df.drop(['approxdate','country','region','vicinity','doubtterr','alternative','multiple','attacktype1','attacktype2','attacktype3','targtype1','targtype2','targtype3','targsubtype1','targsubtype2','targsubtype3','corp3','corp1','corp2','natlty1','natlty2','natlty3','weaptype1','weaptype2','weaptype3','weapsubtype1','weapsubtype2','weapsubtype3','claimed','claimmode','claim2','claim3','claimmode2','claimmode3','compclaim','weaptype1','weapsubtype4','weaptype4','nkillus','nkillter','nwoundus','propextent','kidhijcountry','hostkidoutcome','INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
       'related','propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
       'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert', 'ransom',
       'ransomamt', 'ransomamtus', 'ransompaid', 'ransompaidus',
       'ransomnote', 'hostkidoutcome_txt', 'nreleased', 'addnotes',
       'scite1', 'scite2', 'scite3', 'dbsource', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3','guncertain1', 'guncertain2', 'guncertain3','weaptype1_txt',
       'weapsubtype1_txt', 'weaptype2_txt', 'weapsubtype2_txt',
       'weaptype3_txt', 'weapsubtype3_txt', 'weaptype4_txt','nperps', 'nperpcap','claimmode2_txt','claimmode3_txt','nwoundte', 'crit1',
       'crit2', 'crit3','natlty1_txt','natlty2_txt','natlty3_txt','individual','targtype2_txt','targtype3_txt','targsubtype3_txt','targsubtype2_txt','motive','weapdetail','attacktype3_txt','attacktype2_txt','target2','target3','alternative_txt','weapsubtype4_txt','resolution','claimmode_txt','location','extended'],axis=1)
data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'country_txt', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'summary', 'success', 'suicide', 'attacktype1_txt',
#        'targtype1_txt', 'targsubtype1_txt', 'target1', 'gname', 'nkill',
#        'nwound', 'property'], dtype=object)

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday         country_txt  \
# 0  197000000001   1970       7     2  Dominican Republic
# 1  197000000002   1970       0     0              Mexico
# 2  197001000001   1970       1     0         Philippines
# 3  197001000002   1970       1     0              Greece
# 4  197001000003   1970       1     0               Japan
#
#                     region_txt provstate           city   latitude  \
# 0  Central America & Caribbean       NaN  Santo Domingo  18.456792
# 1                North America   Federal    Mexico city  19.371887
# 2               Southeast Asia    Tarlac        Unknown  15.478598
# 3               Western Europe    Attica         Athens  37.997490
# 4                    East Asia   Fukouka        Fukouka  33.580412
#
#     longitude  ...  success suicide                 attacktype1_txt  \
# 0  -69.951164  ...        1       0                   Assassination
# 1  -99.086624  ...        1       0     Hostage Taking (Kidnapping)
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   eventid           181691 non-null  int64
#  1   iyear             181691 non-null  int64
#  2   imonth            181691 non-null  int64
#  3   iday              181691 non-null  int64
#  4   country_txt       181691 non-null  object
#  5   region_txt        181691 non-null  object
#  6   provstate         181270 non-null  object
#  7   city              181257 non-null  object
#  8   latitude          177135 non-null  float64
#  9   longitude         177134 non-null  float64
#  10  specificity       181685 non-null  float64
#  11  summary           115562 non-null  object
#  12  success           181691 non-null  int64
#  13  suicide           181691 non-null  int64
#  14  attacktype1_txt   181691 non-null  object
#  15  targtype1_txt     181691 non-null  object
# ...

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             latitude     longitude    specificity        success  \
# count  177135.000000  1.771340e+05  181685.000000  181691.000000
# mean       23.498343 -4.586957e+02       1.451452       0.889598
# std        18.569242  2.047790e+05       0.995430       0.313391
# min       -53.154613 -8.618590e+07       1.000000       0.000000
# ...

# %% [markdown]
# # visualization of data

# %%
year = data['iyear'].unique()
years_count = data['iyear'].value_counts(dropna = False)
plt.figure(figsize=(18,10))
sns.barplot(x=year,y=years_count)

plt.xticks(rotation = 50)
plt.xlabel('years',fontsize=20)
plt.ylabel('number of attack on each year',fontsize=20)
plt.title('Attacks In years',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Attacks In years')

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday         country_txt  \
# 0  197000000001   1970       7     2  Dominican Republic
# 1  197000000002   1970       0     0              Mexico
# 2  197001000001   1970       1     0         Philippines
# 3  197001000002   1970       1     0              Greece
# 4  197001000003   1970       1     0               Japan
#
#                     region_txt provstate           city   latitude  \
# 0  Central America & Caribbean       NaN  Santo Domingo  18.456792
# 1                North America   Federal    Mexico city  19.371887
# 2               Southeast Asia    Tarlac        Unknown  15.478598
# 3               Western Europe    Attica         Athens  37.997490
# 4                    East Asia   Fukouka        Fukouka  33.580412
#
#     longitude  ...  success suicide                 attacktype1_txt  \
# 0  -69.951164  ...        1       0                   Assassination
# 1  -99.086624  ...        1       0     Hostage Taking (Kidnapping)
# ...

# %%
df = data[['iyear','nkill']].groupby(['iyear']).sum()
fig, ax4 = plt.subplots(figsize=(20,10))
df.plot(kind='bar',alpha=0.7,ax=ax4)
plt.xticks(rotation = 50)
plt.title("People Died Due To Attack",fontsize=25)
plt.ylabel("Number of killed peope",fontsize=20)
plt.xlabel('Year',fontsize=20)
top_side = ax4.spines["top"]
top_side.set_visible(False)
right_side = ax4.spines["right"]
right_side.set_visible(False)

# %%
plt.figure(figsize=(18,10))
sns.barplot(data['country_txt'].value_counts()[:10].index,data['country_txt'].value_counts()[:10].values)
plt.xticks(rotation=60)
plt.xlabel('region of attack',fontsize=40)
plt.ylabel('counts',fontsize=40)
plt.title('Most Affected Countries',fontsize=40)
# Out:
# C:\Users\aksha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Most Affected Countries')

# %%
pd.crosstab(data.iyear, data.region_txt).plot(kind='area',stacked=False,figsize=(20,10))
plt.title('Terrorist Activities By Region In Each Year',fontsize=25)
plt.ylabel('Number of Attacks',fontsize=20)
plt.xlabel("Year",fontsize=20)
plt.show()

# %%
#most affected city

# %%
data['city'].value_counts().to_frame().sort_values('city',axis=0,ascending=False).head(10).plot(kind='bar',figsize=(20,10),color='grey')
plt.xticks(rotation = 50)
plt.xlabel("City",fontsize=15)
plt.ylabel("Number of attack",fontsize=15)
plt.title("Top 10 most effected city",fontsize=20)
plt.show()

# %%
#type of attack

# %%
data['attacktype1_txt'].value_counts().plot(kind='bar',figsize=(20,10),color='Green')
plt.xticks(rotation = 50)
plt.xlabel("Attacktype",fontsize=15)
plt.ylabel("Number of attack",fontsize=15)
plt.title("Name of attacktype",fontsize=20)
plt.show()

# %%
#maximum number of people died due to what attack

# %%
data[['attacktype1_txt','nkill']].groupby(["attacktype1_txt"],axis=0).sum().plot(kind='bar',figsize=(20,10),color=['black'])
plt.xticks(rotation=50)
plt.title("Number of killed ",fontsize=20)
plt.ylabel('Number of people',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.show()

# %%
#maximum number of people wounded due to what attack

# %%
data[['attacktype1_txt','nwound']].groupby(["attacktype1_txt"],axis=0).sum().plot(kind='bar',figsize=(20,10),color=['brown'])
plt.xticks(rotation=50)
plt.title("Number of wounded  ",fontsize=20)
plt.ylabel('Number of people',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.show()

# %%
data['gname'].value_counts().to_frame().drop('Unknown').head(10).plot(kind='bar',color='violet',figsize=(20,10))
plt.title("Top 10 terrorist group attack",fontsize=20)
plt.xlabel("terrorist group name",fontsize=15)
plt.ylabel("Attack number",fontsize=15)
plt.show()

# %%
df=data[['gname','country_txt','nkill']]
df=df.groupby(['gname','country_txt'],axis=0).sum().sort_values('nkill',ascending=False).drop('Unknown').reset_index().head(10)
df
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_11488\2597127300.py:2: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df=df.groupby(['gname','country_txt'],axis=0).sum().sort_values('nkill',ascending=False).drop('Unknown').reset_index().head(10)
#                                               gname  country_txt    nkill
# 0       Islamic State of Iraq and the Levant (ISIL)         Iraq  31058.0
# 1                                           Taliban  Afghanistan  29269.0
# 2                                        Boko Haram      Nigeria  16917.0
# 3                                 Shining Path (SL)         Peru  11595.0
# 4           Liberation Tigers of Tamil Eelam (LTTE)    Sri Lanka  10928.0
# 5                                        Al-Shabaab      Somalia   8176.0
# 6  Farabundo Marti National Liberation Front (FMLN)  El Salvador   8019.0
# 7       Islamic State of Iraq and the Levant (ISIL)        Syria   6883.0
# ...

# %%
kill = data.loc[:,'nkill']
print('Number of people killed by terror attack:', int(sum(kill.dropna())))
# Out:
# Number of people killed by terror attack: 411868

# %% [markdown]
# # observations

# %% [markdown]
# # MOST AFFECTED COUNTRY IS: IRAQ

# %% [markdown]
# # MOST AFFECTED REGION IS : MIDDLE EAST AND NORTH AFRICA

# %% [markdown]
# # MOST OF THE ATTACK HAPPENED IN 1970

# %% [markdown]
# # GROUP WITH MOST ATTACK IN TAIBAN

# %% [markdown]
# # MAXIMUM NUMBER OF PEOPLE WOUNDED BY BOMBING / EXPLOSION

# %% [markdown]
# # MAXIMUM PEOPLE DIED DUE TO ARMED ASSAULT

# %% [markdown]
# # MOST OF THE PEOPLE DIED IN THE ATTACK IN THE YEAR 2014
