# %% [markdown]
# # Lets Grow More VIP INTERNSHP

# %% [markdown]
# # Iris Flower Classification ML Project

# %% [markdown]
# #  Beginner level Task1

# %% [markdown]
# # Name : K.Akshaya

# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
iris.feature_names

# %%
iris.target_names

# %%
df = pd.DataFrame(iris.data,columns = iris.feature_names)

# %%
df.head()

# %%
df['target']=iris.target

# %%
df['flower_name'] = df.target.apply(lambda x: iris.target_names[x])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
df[45:60]
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 45                4.8               3.0                1.4               0.3
# 46                5.1               3.8                1.6               0.2
# 47                4.6               3.2                1.4               0.2
# 48                5.3               3.7                1.5               0.2
# 49                5.0               3.3                1.4               0.2
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
# 55                5.7               2.8                4.5               1.3
# ...

# %%
df[100:]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
# 105                7.6               3.0                6.6               2.1
# 106                4.9               2.5                4.5               1.7
# 107                7.3               2.9                6.3               1.8
# 108                6.7               2.5                5.8               1.8
# 109                7.2               3.6                6.1               2.5
# 110                6.5               3.2                5.1               2.0
# ...

# %%
#1st 50 is setosa
#2nd is versicolor
#3rd is viginica

# %%
df0=df[0:50]
df1=df[50:100]
df2 = df[100:]

# %%
#analyzing the data set using plots
#scatter plot for sepal length vs sepal width

# %%
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.scatter(df0['sepal length (cm)'],df0['sepal width (cm)'],color = 'black',marker='*')
plt.scatter(df1['sepal length (cm)'],df1['sepal width (cm)'],color ='orange', marker = '^')
plt.scatter(df2['sepal length (cm)'],df2['sepal width (cm)'],color ='yellow' , marker='+')

# %% [markdown]
# # scatter plot for petal length vs petal width

# %%
plt.xlabel('petal length')
plt.ylabel('petal width')
plt.scatter(df0['petal length (cm)'],df0['petal width (cm)'],color = 'green',marker='*')
plt.scatter(df1['petal length (cm)'],df1['petal width (cm)'],color ='blue', marker = '.')

# %%
sns.boxplot(x='flower_name',y='petal length (cm)',data=df)
# Out:
# <AxesSubplot:xlabel='flower_name', ylabel='petal length (cm)'>

# %%
sns.pairplot(df,hue='flower_name',hue_order=df['flower_name'])

# %% [markdown]
# # spliting training and test dataset

# %%
x= df.drop(['target','flower_name'],axis='columns')
y=df.target

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2 ,random_state=1)

# %% [markdown]
# # KNN algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier
model =KNeighborsClassifier(n_neighbors=10)

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
model.score(x_test,y_test)
# Out:
# 0.9666666666666667

# %%
from sklearn.metrics import confusion_matrix

# %%
y_predict = model.predict(x_test)
conf = confusion_matrix(y_predict,y_test)
conf
# Out:
# array([[11,  0,  0],
#        [ 0, 12,  0],
#        [ 0,  1,  6]], dtype=int64)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.92      0.96        13
#            2       0.86      1.00      0.92         6
#
#     accuracy                           0.97        30
#    macro avg       0.95      0.97      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %%
plt.figure(figsize=(7,5))
sns.heatmap(conf,annot=True)
plt.xlabel('predicted')
plt.ylabel('actul value')
# Out:
# Text(42.0, 0.5, 'actul value')

# %% [markdown]
# # Random forest algotithm

# %%
from sklearn.ensemble import RandomForestClassifier
model1 = RandomForestClassifier()
model1.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model1.score(x_test,y_test)
# Out:
# 0.9666666666666667

# %%
from sklearn.metrics import confusion_matrix

# %%
y_prediction = model.predict(x_test)
con = confusion_matrix(y_prediction,y_test)
con
# Out:
# array([[11,  0,  0],
#        [ 0, 12,  0],
#        [ 0,  1,  6]], dtype=int64)

# %%
plt.figure(figsize=(10,7))
sns.heatmap(con,annot=True)
plt.xlabel('predicted')
plt.ylabel('true value')
# Out:
# Text(69.0, 0.5, 'true value')

# %% [markdown]
# # linear regression

# %%
from sklearn.linear_model import LinearRegression
model2 = LinearRegression()
model2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model2.score(x_test,y_test)
# Out:
# 0.8843648990647471

# %% [markdown]
#
# # Accuracy of KNN model is 96%
# # Accuracy of Random Forest is 96%
# # Accuracy of Linear Regression is 88%

# %% [markdown]
# # so we can use either KNN or Random Forest algorithm
